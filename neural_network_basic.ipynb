# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
observations=1000
xs=np.random.uniform(low=-10,high=10,size=(observations,1))
zs=np.random.uniform(-10,10,(observations,1))
inputs=np.column_stack((xs,zs))
print(inputs.shape)
# Out:
# (1000, 2)

# %%
noise=np.random.uniform(-1,-1,(observations,1))
targets=2*xs-3*zs+5+noise
print(targets.shape)
# Out:
# (1000, 1)

# %%
targets=targets.reshape(observations,)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()
targets=targets.reshape(observations,1)

# %%
init_range=0.1
weights=np.random.uniform(-init_range,init_range,size=(2,1))
biases=np.random.uniform(-init_range,init_range,size=1)
print(weights)
print(biases)
# Out:
# [[-0.09899162]
#  [ 0.03483926]]
# [0.03260981]

# %%
learning_rate=0.02

# %%
for i in range(100):
    outputs=np.dot(inputs,weights)+biases
    deltas=outputs-targets
    loss=np.sum(deltas**2)/2/observations
    print(loss)
    
    deltas_scaled=deltas/observations
    weights=weights-learning_rate*np.dot(inputs.T,deltas_scaled)
    biases=biases-learning_rate*np.sum(deltas_scaled)
# Out:
# 0.0024651302880140504
# 0.002367846220515415
# 0.0022744013780002107
# 0.0021846442490353903
# 0.002098429301445395
# 0.002015616746346172
# 0.0019360723114916203
# 0.0018596670235645973
# 0.0017862769990595682
# 0.0017157832434180414
# 0.0016480714580908264
# 0.0015830318552141835
# 0.001520558979600326
# 0.001460551537751783
# 0.0014029122336246549
# 0.0013475476108726076
# 0.0012943679013167903
# 0.0012432868793959574
# 0.0011942217223601097
# 0.0011470928759817712
# 0.0011018239255669332
# 0.001058341472056199
# 0.0010165750130155973
# 0.0009764568283238941
# 0.0009379218703713528
# 0.0009009076585914246
# 0.0008653541781549123
# 0.0008312037826617379
# 0.0007984011006733885
# 0.000766892945933444
# 0.0007366282311314909
# 0.0007075578850701794
# 0.0006796347731012116
# 0.0006528136207011586
# 0.0006270509400635268
# 0.0006023049595874242
# 0.0005785355561493454
# 0.0005557041900473516
# 0.0005337738425128973
# 0.0005127089556886551
# 0.0004924753749749479
# 0.0004730402936514862
# 0.00045437219968463415
# 0.0004364408246337918
# 0.00041921709457403637
# 0.0004026730829559114
# 0.0003867819653250818
# 0.000371517975829319
# 0.0003568563654417142
# 0.00034277336183263703
# 0.0003292461308252661
# 0.00031625273937223986
# 0.0003037721199934934
# 0.0002917840366173888
# 0.0002802690517700166
# 0.00026920849505918874
# 0.00025858443290236415
# 0.00024837963944909856
# 0.00023857756865109173
# 0.00022916232743434742
# 0.00022011864993030095
# 0.00021143187272358176
# 0.00020308791107685165
# 0.0001950732360937733
# 0.00018737485278333882
# 0.0001799802789896645
# 0.00017287752515357996
# 0.00016605507487262494
# 0.00015950186622846473
# 0.00015320727385102255
# 0.00014716109169055525
# 0.0001413535164695603
# 0.00013577513178773142
# 0.00013041689285420665
# 0.00012527011182234793
# 0.0001203264437033378
# 0.00011557787283549038
# 0.00011101669988777204
# 0.00010663552937607898
# 0.00010242725767213348
# 9.838506148578329e-05
# 9.450238680162199e-05
# 9.077293825235114e-05
# 8.71906689114879e-05
# 8.374977048885043e-05
# 8.044466391299843e-05
# 7.726999028538395e-05
# 7.422060219132536e-05
# 7.129155535413622e-05
# 6.847810061834527e-05
# 6.577567624949343e-05
# 6.317990053770514e-05
# 6.0686564693206374e-05
# 5.829162602218137e-05
# 5.5991201371963795e-05
# 5.3781560834875664e-05
# 5.1659121700568176e-05
# 4.962044264702453e-05
# 4.76622181607744e-05
# 4.578127317736477e-05

# %%
print(weights,biases)
# Out:
# [[ 2.00009726]
#  [-3.00000755]] [3.99060609]

# %%
plt.plot(outputs,targets)
plt.xlabel('outputs')
plt.ylabel('inputs')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
